# %%
import pandas as pd

# %%
cities_df = pd.read_csv('resources\cities.csv', index_col=None)
cities_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Albany           1      US  1573966941        78  42.65  -73.75
# 1             Faya          62      SA  1573967103        71  18.39   42.45
# 2         Hukuntsi           0      BW  1573967103        11 -23.98   21.76
# 3  Haines Junction         100      CA  1573967103        97  60.75 -137.51
# 4         Salvador          40      BR  1573967103        78 -12.98  -38.48
#
#    Max Temp  Wind Speed
# 0     21.00        1.61
# 1     53.60        5.97
# 2     80.64       10.04
# 3     23.31        2.80
# 4     80.60       11.41

# %%
html = cities_df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Albany</td>
#       <td>1</td>
#       <td>US</td>
#       <td>1573966941</td>
#       <td>78</td>
#       <td>42.65</td>
#       <td>-73.75</td>
#       <td>21.00</td>
#       <td>1.61</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Faya</td>
#       <td>62</td>
#       <td>SA</td>
#       <td>1573967103</td>
#       <td>71</td>
#       <td>18.39</td>
#       <td>42.45</td>
#       <td>53.60</td>
#       <td>5.97</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hukuntsi</td>
#       <td>0</td>
#       <td>BW</td>
#       <td>1573967103</td>
#       <td>11</td>
# ...
